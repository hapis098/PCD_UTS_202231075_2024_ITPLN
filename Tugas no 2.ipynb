# %%
# Import library yang diperlukan
import cv2
import numpy as np

# %%
# Baca citra
img = cv2.imread('citrahafidz.jpg')

# %%
# Konversi gambar ke warna HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
# Mendefinisikan warna untuk biru, merah, dan hijau
biru_bawah = np.array([100, 43, 46])
biru_atas = np.array([130, 255, 255])

merah_bawah = np.array([160, 43, 46])
merah_atas = np.array([180, 255, 255])

hijau_bawah = np.array([36, 43, 46])
hijau_atas = np.array([70, 255, 255])

# %%
# Membentuk pelindung berbeda untuk masing-masing warna.
merah_mask = cv2.inRange(hsv, merah_bawah, merah_atas)
hijau_mask = cv2.inRange(hsv, hijau_bawah, hijau_atas)
biru_mask = cv2.inRange(hsv, biru_bawah, biru_atas)

# %%
# Menemukan piksel yang cocok dengan setiap warna
merah_piksel = cv2.bitwise_and(img, img, mask=merah_mask)
hijau_piksel = cv2.bitwise_and(img, img, mask=hijau_mask)
biru_piksel = cv2.bitwise_and(img, img, mask=biru_mask)

# %%
# Menampilkan citra asli dan citra yang dideteksi
cv2.imshow('Image Asli', img)
cv2.imshow('merah', merah_piksel)
cv2.imshow('Hijau', hijau_piksel)
cv2.imshow('Biru', biru_piksel)

# Tunggu tombol ditekan untuk keluar
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot
import matplotlib.pyplot as plt

# %%
# Tampilkan citra asli dan citra yang dideteksi menggunakan matplotlib
plt.figure(figsize=(10, 5))

# %%
# Citra Asli
plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Citra Asli')
plt.axis('off')
# Out:
# (-0.5, 2159.5, 1901.5, -0.5)

# %%
# Citra Biru
plt.subplot(2, 2, 2)
plt.imshow(cv2.cvtColor(biru_piksel, cv2.COLOR_BGR2RGB))
plt.title('Biru')
plt.axis('off')
# Out:
# (-0.5, 2159.5, 1901.5, -0.5)

# %%
# Citra Merah
plt.subplot(2, 2, 3)
plt.imshow(cv2.cvtColor(merah_piksel, cv2.COLOR_BGR2RGB))
plt.title('Merah')
plt.axis('off')
# Out:
# (-0.5, 2159.5, 1901.5, -0.5)

# %%
# Citar Hijau
plt.subplot(2, 2, 4)
plt.imshow(cv2.cvtColor(hijau_piksel, cv2.COLOR_BGR2RGB))
plt.title('Hijau')
plt.axis('off')
# Out:
# (-0.5, 2159.5, 1901.5, -0.5)

# %%
plt.tight_layout()
plt.show()

# %%
# citra Asli
plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB))
plt.title('Gambar Asli')
plt.axis('off')

# citra Biru
plt.subplot(2, 2, 2)
plt.imshow(cv2.cvtColor(biru_piksel, cv2.COLOR_BGR2RGB))
plt.title('Biru')
plt.axis('off')

# citra Merah
plt.subplot(2, 2, 3)
plt.imshow(cv2.cvtColor(merah_piksel, cv2.COLOR_BGR2RGB))
plt.title('Merah')
plt.axis('off')

# citra Hijau
plt.subplot(2, 2, 4)
plt.imshow(cv2.cvtColor(hijau_piksel, cv2.COLOR_BGR2RGB))
plt.title('Hijau')
plt.axis('off')
plt.savefig('ambang batas cita.png')
plt.tight_layout()
plt.show()
